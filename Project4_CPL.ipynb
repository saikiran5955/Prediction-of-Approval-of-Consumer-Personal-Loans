# %% [markdown]
# # Prediction of Approval of Consumer Personal Loans Applications

# %%
import pandas as pd
import numpy as np

dfTrain = pd.read_excel('Project - 4 - Train Data (1).xlsx')
dfTest = pd.read_excel('Project - 4 - Test Data (1).xlsx')

# %%
dfTrain
# Out:
#     Loanapp_ID Sex Marital_Status first_name    last_name  \
# 0    CPL001002   M              N     Austin    Pennycook
# 1    CPL001003   M              Y     Mareah      Tomanek
# 2    CPL001005   M              Y      Myrna  Rosenthaler
# 3    CPL001006   M              Y   Danyette       Stempe
# 4    CPL001008   M              N     Patten      McCathy
# ..         ...  ..            ...        ...          ...
# 609  CPL002978   F              N     Farlay      Stoakes
# 610  CPL002979   M              Y     Nestor        Saben
# 611  CPL002983   M              Y  Stanleigh     Le Fevre
# 612  CPL002984   M              Y     Amalle     Whitmell
# 613  CPL002990   F              N      Gilly     Gauchier
#
#                            email                     address Dependents  \
# 0            apennycook1@mac.com             007 Miller Road          0
# 1        mtomanek2@bloomberg.com  145 Charing Cross Junction          1
# 2         mrosenthaler3@dmoz.org             268 Algoma Hill          0
# 3            dstempe4@tumblr.com       571 Stone Corner Park          0
# 4              pmccathy5@ted.com           118 Moulton Drive          0
# ..                           ...                         ...        ...
# 609      fstoakeso6@multiply.com               7 Dixon Point          0
# 610           nsabeno8@google.es          7590 Almo Crossing         3+
# 611  slefevreo9@biblegateway.com          532 Hoepker Street          1
# 612          awhitmelloa@ftc.gov           6417 Gerald Alley          2
# 613    ggauchierob@artisteer.com          37 Ruskin Crossing          0
#
#      Qual_var SE  App_Income_1  App_Income_2  CPL_Amount  CPL_Term  \
# 0        Grad  N        7018.8           0.0         NaN     360.0
# 1        Grad  N        5499.6        1809.6       153.6     360.0
# 2        Grad  Y        3600.0           0.0        79.2     360.0
# 3    Non Grad  N        3099.6        2829.6       144.0     360.0
# 4        Grad  N        7200.0           0.0       169.2     360.0
# ..        ... ..           ...           ...         ...       ...
# 609      Grad  N        3480.0           0.0        71.0     360.0
# 610      Grad  N        4927.2           0.0        40.0     180.0
# 611      Grad  N        9686.4         288.0       253.0     360.0
# 612      Grad  N        9099.6           0.0       187.0     360.0
# 613      Grad  Y        5499.6           0.0       133.0     360.0
#
#      Credit_His Prop_Area      INT_ID      Prev_ID  \
# 0           1.0     Urban  9694176212  92-247-0058
# 1           1.0     Rural   152387684  36-236-3028
# 2           1.0     Urban  6510396556  34-339-0917
# 3           1.0     Urban  7141853006  94-098-8902
# 4           1.0     Urban    23293411  38-247-1410
# ..          ...       ...         ...          ...
# 609         1.0     Rural  7970371132  71-281-1408
# 610         1.0     Rural  5389023404  94-349-9755
# 611         1.0     Urban  5977024495  70-685-8094
# 612         1.0     Urban  3077859882  09-770-7899
# 613         0.0    Semi U  5248569311  58-618-0693
#
#                                                 AGT_ID CPL_Status
# 0    Mozilla/5.0 (Windows; U; Windows NT 5.1; zh-TW...          Y
# 1    Mozilla/5.0 (Windows NT 5.1; rv:21.0) Gecko/20...          N
# 2    Mozilla/5.0 (Windows; U; Windows NT 6.1; cs-CZ...          Y
# 3    Mozilla/5.0 (iPhone; U; CPU iPhone OS 4_2_1 li...          Y
# 4    Mozilla/5.0 (Windows NT 6.0; WOW64) AppleWebKi...          Y
# ..                                                 ...        ...
# 609  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.8...          Y
# 610  Mozilla/5.0 (Windows NT 6.0; WOW64; rv:24.0) G...          Y
# 611  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...          Y
# 612  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...          Y
# 613  Mozilla/5.0 (Windows; U; Windows NT 5.1; ru-RU...          N
#
# [614 rows x 20 columns]

# %%
dfTest
# Out:
#     Loanapp_ID Sex Marital_Status first_name last_name  \
# 0    CPL001015   M              Y     Dollie     Scafe
# 1    CPL001022   M              Y        Kim      Arne
# 2    CPL001031   M              Y    Niccolo    Ramble
# 3    CPL001035   M              Y      Rabbi      Haig
# 4    CPL001051   M              N     Gracie    Winear
# ..         ...  ..            ...        ...       ...
# 362  CPL002971   M              Y    Kendall  Stuttman
# 363  CPL002975   M              Y    Brianna      Pash
# 364  CPL002980   M              N  Beniamino     Dreus
# 365  CPL002986   M              Y       Judd    Towsie
# 366  CPL002989   M              N   Clerissa     Sarre
#
#                          email                  address Dependents  Qual_var  \
# 0                dscafe0@is.gd         02 Garrison Pass          0      Grad
# 1        karne9@infoseek.co.jp        6568 Dwight Point          1      Grad
# 2              nramblef@gov.uk         3504 Lukken Park          2      Grad
# 3               rhaigg@tiny.cc        1334 Florence Way          2      Grad
# 4          gwinearj@devhub.com  9800 Ridge Oak Crossing          0  Non Grad
# ..                         ...                      ...        ...       ...
# 362   kstuttmanpc@yolasite.com          463 School Park         3+  Non Grad
# 363  bpashpd@deliciousdays.com          80 Forster Pass          0      Grad
# 364   bdreuspg@nydailynews.com        615 Hallows Point          0      Grad
# 365   jtowsieph@altervista.org       85 Arapahoe Street          0      Grad
# 366       csarrepk@comcast.net     28876 Cambridge Pass          0      Grad
#
#     SE  App_Income_1  App_Income_2  CPL_Amount  CPL_Term  Credit_His  \
# 0    N        6864.0           0.0       132.0     360.0         1.0
# 1    N        3691.2        1800.0       151.2     360.0         1.0
# 2    N        6000.0        2160.0       249.6     360.0         1.0
# 3    N        2808.0        3055.2       120.0     360.0         NaN
# 4    N        3931.2           0.0        93.6     360.0         1.0
# ..  ..           ...           ...         ...       ...         ...
# 362  Y        4810.8        2132.4       113.0     360.0         1.0
# 363  N        4989.6         850.8       115.0     360.0         1.0
# 364  N        3900.0        2391.6       126.0     360.0         NaN
# 365  N        6000.0        2871.6       158.0     360.0         1.0
# 366  Y       11040.0           0.0        98.0     180.0         1.0
#
#          INT_ID      Prev_ID  \
# 0    6869736235  79-489-1539
# 1    3383749711  75-757-9174
# 2    7247894032  42-085-4345
# 3    3240492342  10-813-9695
# 4    1670564037  20-195-4948
# ..          ...          ...
# 362  6577741441  06-834-0940
# 363  9721903779  86-581-4311
# 364  5200766958  15-578-5734
# 365  8258117459  61-064-0986
# 366  9787209609  87-766-7792
#
#                                                 AGT_ID Prop_Area
# 0    Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_6...     Urban
# 1    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_2)...     Urban
# 2    Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...     Urban
# 3    Mozilla/5.0 (X11; Linux i686) AppleWebKit/534....     Urban
# 4    Mozilla/5.0 (Windows NT 6.0) AppleWebKit/534.2...     Urban
# ..                                                 ...       ...
# 362  Mozilla/5.0 (X11; Linux i686) AppleWebKit/534....     Urban
# 363  Mozilla/5.0 (X11; Linux i686) AppleWebKit/535....     Urban
# 364  Mozilla/5.0 (X11; CrOS i686 2268.111.0) AppleW...    Semi U
# 365  Mozilla/5.0 (Windows NT 6.0) AppleWebKit/535.1...     Rural
# 366  Mozilla/5.0 (Windows; U; Windows NT 6.0; ja-JP...     Rural
#
# [367 rows x 19 columns]

# %%
new_df=dfTrain.drop(['Loanapp_ID', 'Sex', 'Marital_Status','first_name','last_name','email','address','AGT_ID','INT_ID','Prev_ID'], axis=1)
print("Median values :")
print(new_df.median(axis = 0))
new_df['SE'].fillna( method ='ffill', inplace = True)
new_df['Dependents'].fillna( method ='ffill', inplace = True)
new_df['CPL_Amount'].fillna((new_df['CPL_Amount'].median()), inplace=True)
new_df['CPL_Term'].fillna((new_df['CPL_Term'].median()), inplace=True)
new_df['Credit_His'].fillna((new_df['Credit_His'].median()), inplace=True)
new_df['Dependents'].replace({"3+": 4}, inplace=True)
# Out:
# Median values :
# App_Income_1    4575.0
# App_Income_2    1426.2
# CPL_Amount       153.6
# CPL_Term         360.0
# Credit_His         1.0
# dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder 
  
le = LabelEncoder() 
  
new_df['Qual_var']= le.fit_transform(new_df['Qual_var']) #Grad=0,Nongrad=1
new_df['SE']= le.fit_transform(new_df['SE']) #N=0,Y=1
new_df['Prop_Area']= le.fit_transform(new_df['Prop_Area']) #urban=2,rural=0,semi urban=1
new_df['CPL_Status']= le.fit_transform(new_df['CPL_Status']) #Y=1,N=0
new_df['Net_income']=new_df['App_Income_1']+new_df['App_Income_2']
new_df.head()
# Out:
#    Dependents  Qual_var  SE  App_Income_1  App_Income_2  CPL_Amount  CPL_Term  \
# 0           0         0   0        7018.8           0.0       153.6     360.0
# 1           1         0   0        5499.6        1809.6       153.6     360.0
# 2           0         0   1        3600.0           0.0        79.2     360.0
# 3           0         1   0        3099.6        2829.6       144.0     360.0
# 4           0         0   0        7200.0           0.0       169.2     360.0
#
#    Credit_His  Prop_Area  CPL_Status  Net_income
# 0         1.0          2           1      7018.8
# 1         1.0          0           0      7309.2
# 2         1.0          2           1      3600.0
# 3         1.0          2           1      5929.2
# 4         1.0          2           1      7200.0

# %%
from sklearn import preprocessing

scaler = preprocessing.MinMaxScaler()
min_max_scaler = preprocessing.MinMaxScaler()
def scaleColumns(df, cols_to_scale):
    for col in cols_to_scale:
        df[col] = pd.DataFrame(min_max_scaler.fit_transform(pd.DataFrame(new_df[col])),columns=[col])
    return df

scaled_df = scaleColumns(new_df,['CPL_Amount','CPL_Term','Net_income'])
scaled_df.head()
# Out:
#    Dependents  Qual_var  SE  App_Income_1  App_Income_2  CPL_Amount  CPL_Term  \
# 0           0         0   0        7018.8           0.0    0.172214   0.74359
# 1           1         0   0        5499.6        1809.6    0.172214   0.74359
# 2           0         0   1        3600.0           0.0    0.082489   0.74359
# 3           0         1   0        3099.6        2829.6    0.160637   0.74359
# 4           0         0   0        7200.0           0.0    0.191027   0.74359
#
#    Credit_His  Prop_Area  CPL_Status  Net_income
# 0         1.0          2           1    0.055394
# 1         1.0          0           0    0.058435
# 2         1.0          2           1    0.019583
# 3         1.0          2           1    0.043980
# 4         1.0          2           1    0.057292

# %%
scaled_df.corr()
# Out:
#               Dependents  Qual_var        SE  App_Income_1  App_Income_2  \
# Dependents      1.000000  0.058366  0.036554      0.131576      0.031691
# Qual_var        0.058366  1.000000 -0.008734     -0.140760     -0.062290
# SE              0.036554 -0.008734  1.000000      0.122728     -0.021807
# App_Income_1    0.131576 -0.140760  0.122728      1.000000     -0.116605
# App_Income_2    0.031691 -0.062290 -0.021807     -0.116605      1.000000
# CPL_Amount      0.115739 -0.109693 -0.028932      0.023228      0.094974
# CPL_Term       -0.090302 -0.073928 -0.027941     -0.046531     -0.059383
# Credit_His     -0.068343 -0.073658  0.006209     -0.018615      0.011134
# Prop_Area      -0.007517 -0.065243 -0.037106     -0.009500      0.010522
# CPL_Status     -0.008747 -0.085884  0.009035     -0.004710     -0.059187
# Net_income      0.138812 -0.161362  0.106204      0.893037      0.342781
#
#               CPL_Amount  CPL_Term  Credit_His  Prop_Area  CPL_Status  \
# Dependents      0.115739 -0.090302   -0.068343  -0.007517   -0.008747
# Qual_var       -0.109693 -0.073928   -0.073658  -0.065243   -0.085884
# SE             -0.028932 -0.027941    0.006209  -0.037106    0.009035
# App_Income_1    0.023228 -0.046531   -0.018615  -0.009500   -0.004710
# App_Income_2    0.094974 -0.059383    0.011134   0.010522   -0.059187
# CPL_Amount      1.000000 -0.006964    0.010923   0.017465    0.032853
# CPL_Term       -0.006964  1.000000   -0.004705  -0.076120   -0.022549
# Credit_His      0.010923 -0.004705    1.000000   0.001963    0.540556
# Prop_Area       0.017465 -0.076120    0.001963   1.000000    0.032112
# CPL_Status      0.032853 -0.022549    0.540556   0.032112    1.000000
# Net_income      0.065001 -0.070917   -0.012563  -0.004218   -0.031271
#
#               Net_income
# Dependents      0.138812
# Qual_var       -0.161362
# SE              0.106204
# App_Income_1    0.893037
# App_Income_2    0.342781
# CPL_Amount      0.065001
# CPL_Term       -0.070917
# Credit_His     -0.012563
# Prop_Area      -0.004218
# CPL_Status     -0.031271
# Net_income      1.000000

# %%
import seaborn as sns
sns.pairplot(scaled_df, hue='CPL_Status', diag_kind='kde', height=2)
# Out:
# C:\Users\SaiKiran\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\SaiKiran\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
from sklearn.model_selection import train_test_split
X = scaled_df[[ 'Qual_var','CPL_Amount','Net_income','CPL_Term','Credit_His','Prop_Area']]
y = scaled_df['CPL_Status']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0,test_size=0.20)

# %% [markdown]
# Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=0).fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.6910569105691057

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC
from sklearn import svm
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix 
param_grid = {'C': [0.1, 1, 10, 100, 1000],  
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
              'kernel': ['rbf']}  
  
grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3) 
grid.fit(X_train, y_train)
# print best parameter after tuning 
print(grid.best_params_) 
  
# print how our model looks after hyper-parameter tuning 
print(grid.best_estimator_)
# Out:
# C:\Users\SaiKiran\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.817, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.805, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.791, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.677, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.677, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.675, total=   0.0s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.677, total=   0.0s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.677, total=   0.0s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.675, total=   0.0s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.677, total=   0.0s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.677, total=   0.0s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.675, total=   0.0s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.677, total=   0.0s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.677, total=   0.0s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.675, total=   0.0s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.817, total=   0.0s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.805, total=   0.0s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.791, total=   0.0s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.817, total=   0.0s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.805, total=   0.0s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.791, total=   0.0s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.677, total=   0.0s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.677, total=   0.0s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.675, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.677, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.677, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.675, total=   0.0s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.677, total=   0.0s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.677, total=   0.0s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.675, total=   0.0s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.805, total=   0.0s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.799, total=   0.0s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.791, total=   0.0s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.817, total=   0.0s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.805, total=   0.0s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.791, total=   0.0s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.817, total=   0.0s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.805, total=   0.0s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.791, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.677, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.677, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.675, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.677, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.677, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.675, total=   0.0s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.768, total=   0.0s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.793, total=   0.0s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.761, total=   0.0s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.817, total=   0.0s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.805, total=   0.0s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.791, total=   0.0s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.817, total=   0.0s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.805, total=   0.0s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.791, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.817, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.805, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.791, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.677, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.677, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.675, total=   0.0s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.756, total=   0.1s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.780, total=   0.1s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.767, total=   0.0s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.805, total=   0.0s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.805, total=   0.1s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.767, total=   0.1s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.817, total=   0.1s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.805, total=   0.1s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.791, total=   0.1s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.817, total=   0.0s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.805, total=   0.0s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.791, total=   0.0s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.817, total=   0.0s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.805, total=   0.0s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.791, total=   0.0s
# {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=1, kernel='rbf', max_iter=-1,
#     probability=False, random_state=None, shrinking=True, tol=0.001,
#     verbose=False)
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed:    1.9s finished

# %%
clf =svm.SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
  decision_function_shape='ovr', degree=3, gamma=1, kernel='rbf',
  max_iter=-1, probability=False, random_state=None, shrinking=True,
  tol=0.001, verbose=False).fit(X_train,y_train)
clf.score(X_test, y_test)
# Out:
# 0.8292682926829268

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
distances = [ 2, 3, 4, 5,6,7,8,9,10]
train_results = []
test_results = []
for p in distances:
    model = KNeighborsClassifier(p=p)
    model.fit(X_train, y_train)
    train_pred = model.predict(X_train)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(y_train, train_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    train_results.append(roc_auc)
    y_pred = model.predict(X_test)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    test_results.append(roc_auc)
print(train_results)
print(test_results)
# Out:
# [0.7337652496779571, 0.7382833219671137, 0.7412953701598848, 0.7396567401682201, 0.7428013942562703, 0.7365120860801697, 0.7395241342729408, 0.7395241342729408, 0.7395241342729408]
# [0.6787878787878787, 0.6787878787878787, 0.6787878787878787, 0.6787878787878787, 0.6787878787878787, 0.6787878787878787, 0.6787878787878787, 0.6787878787878787, 0.6787878787878787]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import roc_curve, auc, roc_auc_score
knnreg =KNeighborsClassifier(n_neighbors =3).fit(X_train, y_train)
y_pred =knnreg.predict(X_test)
print("ROC_AUC SCORE : {}".format(roc_auc_score(y_test,y_pred)))
print("SCORE : {}".format(knnreg.score(X_test, y_test)))
# Out:
# ROC_AUC SCORE : 0.6676767676767676
# SCORE : 0.7804878048780488

# %% [markdown]
# Random Forest Classifier

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(random_state = 0)
n_estimators = [20,40,50,60,70,80,90,100]
max_depth = [3,5, 8, 15, 25, 30]
min_samples_split = [2, 5, 10, 15,25]
min_samples_leaf = [1, 2, 5,7, 10,15,20] 

hyperF = dict(n_estimators = n_estimators, max_depth = max_depth,  
              min_samples_split = min_samples_split, 
             min_samples_leaf = min_samples_leaf)

gridF = GridSearchCV(forest, hyperF, cv = 3, verbose = 1, 
                      n_jobs = -1)
bestF = gridF.fit(X_train, y_train)
print(bestF.best_params_) 
  
# print how our model looks after hyper-parameter tuning 
print(bestF.best_estimator_)
# Out:
# Fitting 3 folds for each of 1680 candidates, totalling 5040 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:   20.1s
# [Parallel(n_jobs=-1)]: Done 784 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=-1)]: Done 1234 tasks      | elapsed:   41.7s
# [Parallel(n_jobs=-1)]: Done 1784 tasks      | elapsed:   56.9s
# [Parallel(n_jobs=-1)]: Done 2434 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 3184 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 4034 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 4984 tasks      | elapsed:  2.4min
# {'max_depth': 5, 'min_samples_leaf': 7, 'min_samples_split': 25, 'n_estimators': 20}
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=5, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=7, min_samples_split=25,
#                        min_weight_fraction_leaf=0.0, n_estimators=20,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)
# [Parallel(n_jobs=-1)]: Done 5040 out of 5040 | elapsed:  2.4min finished

# %%
RFC= RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=5, max_features='auto', max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=7, min_samples_split=25,
            min_weight_fraction_leaf=0.0, n_estimators=20, n_jobs=None,
            oob_score=False, random_state=0, verbose=0, warm_start=False)
mod= RFC.fit(X_train, y_train)
mod.score(X_test, y_test)
# Out:
# 0.8292682926829268

# %% [markdown]
# Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(random_state=0).fit(X_train, y_train)

clf.score(X_test, y_test)
# Out:
# C:\Users\SaiKiran\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.8292682926829268

# %%
from sklearn.pipeline import Pipeline
pipe = Pipeline([('classifier' ,LogisticRegression(random_state=0) )])

param_grid = [
    {'classifier__penalty' : ['l1', 'l2'],
    'classifier__C' : np.logspace(-10, 10, 40),
    'classifier__solver' : ['liblinear']},
    {'classifier__penalty' : ['l2'],
    'classifier__C' : np.logspace(-10, 10, 40),
    'classifier__solver' : ['lbfgs']}
]


clf = GridSearchCV(pipe, param_grid = param_grid, cv = 5, verbose=True, n_jobs=-1)

best_clf = clf.fit(X_train, y_train)
print(best_clf.best_params_) 
  
# print how our model looks after hyper-parameter tuning 
print(best_clf.best_estimator_)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    0.6s
# {'classifier__C': 0.016037187437513277, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# Pipeline(memory=None,
#          steps=[('classifier',
#                  LogisticRegression(C=0.016037187437513277, class_weight=None,
#                                     dual=False, fit_intercept=True,
#                                     intercept_scaling=1, l1_ratio=None,
#                                     max_iter=100, multi_class='warn',
#                                     n_jobs=None, penalty='l1', random_state=0,
#                                     solver='liblinear', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)
# [Parallel(n_jobs=-1)]: Done 600 out of 600 | elapsed:    3.0s finished

# %%
clf = LogisticRegression(C=0.016037187437513277, class_weight=None, dual=False,
          fit_intercept=True, intercept_scaling=1, max_iter=100,
          multi_class='warn', n_jobs=None, penalty='l1', random_state=0,
          solver='liblinear', tol=0.0001, verbose=0, warm_start=False).fit(X_train, y_train)

clf.score(X_test, y_test)
# Out:
# 0.8292682926829268

# %% [markdown]
# To predict for the test file

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
new_df1=dfTest.drop(['Loanapp_ID', 'Sex', 'Marital_Status','first_name','last_name','email','address','AGT_ID','INT_ID','Prev_ID'], axis=1)
new_df1['SE'].fillna( method ='ffill', inplace = True)
new_df1['Dependents'].fillna( method ='ffill', inplace = True)
new_df1['CPL_Amount'].fillna((new_df1['CPL_Amount'].median()), inplace=True)
new_df1['CPL_Term'].fillna((new_df1['CPL_Term'].median()), inplace=True)
new_df1['Credit_His'].fillna((new_df1['Credit_His'].median()), inplace=True)
  
le = LabelEncoder() 
  
new_df1['Qual_var']= le.fit_transform(new_df1['Qual_var']) #Grad=0,Nongrad=1
new_df1['Prop_Area']= le.fit_transform(new_df1['Prop_Area']) #urban=2,rural=0,semi urban=1
new_df1['Net_income']=new_df1['App_Income_1']+new_df1['App_Income_2']


scaler1 = preprocessing.MinMaxScaler()
min_max_scaler1 = preprocessing.MinMaxScaler()
def scaleColumns(df, cols_to_scale):
    for col in cols_to_scale:
        df[col] = pd.DataFrame(min_max_scaler1.fit_transform(pd.DataFrame(new_df1[col])),columns=[col])
    return df

scaled_df1 = scaleColumns(new_df1,['CPL_Amount','CPL_Term','Net_income'])
scaled_df1.head()
# Out:
#   Dependents  Qual_var SE  App_Income_1  App_Income_2  CPL_Amount  CPL_Term  \
# 0          0         0  N        6864.0           0.0    0.157088  0.746835
# 1          1         0  N        3691.2        1800.0    0.187739  0.746835
# 2          2         0  N        6000.0        2160.0    0.344828  0.746835
# 3          2         0  N        2808.0        3055.2    0.137931  0.746835
# 4          0         1  N        3931.2           0.0    0.095785  0.746835
#
#    Credit_His  Prop_Area  Net_income
# 0         1.0          2    0.055957
# 1         1.0          2    0.039791
# 2         1.0          2    0.071218
# 3         1.0          2    0.044172
# 4         1.0          2    0.021422

# %%
train_df=dfTrain.drop(['Loanapp_ID', 'Sex', 'Marital_Status','first_name','last_name','email','address','AGT_ID','INT_ID','Prev_ID'], axis=1)

train_df['SE'].fillna( method ='ffill', inplace = True)
train_df['Dependents'].fillna( method ='ffill', inplace = True)
train_df['CPL_Amount'].fillna((train_df['CPL_Amount'].median()), inplace=True)
train_df['CPL_Term'].fillna((train_df['CPL_Term'].median()), inplace=True)
train_df['Credit_His'].fillna((train_df['Credit_His'].median()), inplace=True)
 
 
  
train_df['Qual_var']= le.fit_transform(train_df['Qual_var']) #Grad=0,Nongrad=1
train_df['Prop_Area']= le.fit_transform(train_df['Prop_Area']) #urban=2,rural=0,semi urban=1
train_df['Net_income']=train_df['App_Income_1']+train_df['App_Income_2']


scaler2 = preprocessing.MinMaxScaler()
min_max_scaler2 = preprocessing.MinMaxScaler()
def scaleColumns(df, cols_to_scale):
    for col in cols_to_scale:
        df[col] = pd.DataFrame(min_max_scaler2.fit_transform(pd.DataFrame(train_df[col])),columns=[col])
    return df

scaled_df2 = scaleColumns(train_df,['CPL_Amount','CPL_Term','Net_income'])
scaled_df2.head()
# Out:
#   Dependents  Qual_var SE  App_Income_1  App_Income_2  CPL_Amount  CPL_Term  \
# 0          0         0  N        7018.8           0.0    0.172214   0.74359
# 1          1         0  N        5499.6        1809.6    0.172214   0.74359
# 2          0         0  Y        3600.0           0.0    0.082489   0.74359
# 3          0         1  N        3099.6        2829.6    0.160637   0.74359
# 4          0         0  N        7200.0           0.0    0.191027   0.74359
#
#    Credit_His  Prop_Area CPL_Status  Net_income
# 0         1.0          2          Y    0.055394
# 1         1.0          0          N    0.058435
# 2         1.0          2          Y    0.019583
# 3         1.0          2          Y    0.043980
# 4         1.0          2          Y    0.057292

# %%
X_P4train=scaled_df2[[ 'Qual_var','CPL_Amount','Net_income','CPL_Term','Credit_His','Prop_Area']]
y_P4train= scaled_df2['CPL_Status']
X_P4test=scaled_df1[[ 'Qual_var','CPL_Amount','Net_income','CPL_Term','Credit_His','Prop_Area']]

# %% [markdown]
# To predict

# %%
#SVM
Svm =svm.SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
  decision_function_shape='ovr', degree=3, gamma=1, kernel='rbf',
  max_iter=-1, probability=False, random_state=None, shrinking=True,
  tol=0.001, verbose=False).fit(X_P4train,y_P4train)
y_predSVM = Svm.predict(X_P4test)
dfTest['CPL_Status(SVM)']=y_predSVM

# %%
#RANDOM FOREST
RFC= RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=5, max_features='auto', max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=7, min_samples_split=25,
            min_weight_fraction_leaf=0.0, n_estimators=20, n_jobs=None,
            oob_score=False, random_state=0, verbose=0, warm_start=False)
mod= RFC.fit(X_P4train, y_P4train)
y_predRFC = mod.predict(X_P4test)
dfTest['CPL_Status(RFC)']=y_predRFC

# %%
#Logistic
log1 = LogisticRegression(C=0.016037187437513277, class_weight=None, dual=False,
          fit_intercept=True, intercept_scaling=1, max_iter=100,
          multi_class='warn', n_jobs=None, penalty='l1', random_state=0,
          solver='liblinear', tol=0.0001, verbose=0, warm_start=False).fit(X_P4train, y_P4train)
y_predlog = log1.predict(X_P4test)
dfTest['CPL_Status(LOGISTIC)']=y_predlog

# %%
dfTest
# Out:
#     Loanapp_ID Sex Marital_Status first_name last_name  \
# 0    CPL001015   M              Y     Dollie     Scafe
# 1    CPL001022   M              Y        Kim      Arne
# 2    CPL001031   M              Y    Niccolo    Ramble
# 3    CPL001035   M              Y      Rabbi      Haig
# 4    CPL001051   M              N     Gracie    Winear
# ..         ...  ..            ...        ...       ...
# 362  CPL002971   M              Y    Kendall  Stuttman
# 363  CPL002975   M              Y    Brianna      Pash
# 364  CPL002980   M              N  Beniamino     Dreus
# 365  CPL002986   M              Y       Judd    Towsie
# 366  CPL002989   M              N   Clerissa     Sarre
#
#                          email                  address Dependents  Qual_var  \
# 0                dscafe0@is.gd         02 Garrison Pass          0      Grad
# 1        karne9@infoseek.co.jp        6568 Dwight Point          1      Grad
# 2              nramblef@gov.uk         3504 Lukken Park          2      Grad
# 3               rhaigg@tiny.cc        1334 Florence Way          2      Grad
# 4          gwinearj@devhub.com  9800 Ridge Oak Crossing          0  Non Grad
# ..                         ...                      ...        ...       ...
# 362   kstuttmanpc@yolasite.com          463 School Park         3+  Non Grad
# 363  bpashpd@deliciousdays.com          80 Forster Pass          0      Grad
# 364   bdreuspg@nydailynews.com        615 Hallows Point          0      Grad
# 365   jtowsieph@altervista.org       85 Arapahoe Street          0      Grad
# 366       csarrepk@comcast.net     28876 Cambridge Pass          0      Grad
#
#     SE  ...  CPL_Amount  CPL_Term  Credit_His      INT_ID      Prev_ID  \
# 0    N  ...       132.0     360.0         1.0  6869736235  79-489-1539
# 1    N  ...       151.2     360.0         1.0  3383749711  75-757-9174
# 2    N  ...       249.6     360.0         1.0  7247894032  42-085-4345
# 3    N  ...       120.0     360.0         NaN  3240492342  10-813-9695
# 4    N  ...        93.6     360.0         1.0  1670564037  20-195-4948
# ..  ..  ...         ...       ...         ...         ...          ...
# 362  Y  ...       113.0     360.0         1.0  6577741441  06-834-0940
# 363  N  ...       115.0     360.0         1.0  9721903779  86-581-4311
# 364  N  ...       126.0     360.0         NaN  5200766958  15-578-5734
# 365  N  ...       158.0     360.0         1.0  8258117459  61-064-0986
# 366  Y  ...        98.0     180.0         1.0  9787209609  87-766-7792
#
#                                                 AGT_ID Prop_Area  \
# 0    Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_6...     Urban
# 1    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_2)...     Urban
# 2    Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...     Urban
# 3    Mozilla/5.0 (X11; Linux i686) AppleWebKit/534....     Urban
# 4    Mozilla/5.0 (Windows NT 6.0) AppleWebKit/534.2...     Urban
# ..                                                 ...       ...
# 362  Mozilla/5.0 (X11; Linux i686) AppleWebKit/534....     Urban
# 363  Mozilla/5.0 (X11; Linux i686) AppleWebKit/535....     Urban
# 364  Mozilla/5.0 (X11; CrOS i686 2268.111.0) AppleW...    Semi U
# 365  Mozilla/5.0 (Windows NT 6.0) AppleWebKit/535.1...     Rural
# 366  Mozilla/5.0 (Windows; U; Windows NT 6.0; ja-JP...     Rural
#
#     CPL_Status(SVM) CPL_Status(RFC) CPL_Status(LOGISTIC)
# 0                 Y               Y                    Y
# 1                 Y               Y                    Y
# 2                 Y               Y                    Y
# 3                 Y               Y                    Y
# 4                 Y               Y                    Y
# ..              ...             ...                  ...
# 362               Y               Y                    Y
# 363               Y               Y                    Y
# 364               Y               Y                    Y
# 365               Y               Y                    Y
# 366               Y               Y                    Y
#
# [367 rows x 22 columns]
